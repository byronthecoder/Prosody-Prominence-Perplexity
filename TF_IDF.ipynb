# %%
import glob
import pandas as pd
import numpy as np
from scipy.stats.stats import spearmanr
from nltk.stem.lancaster import LancasterStemmer
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfVectorizer
import re
import pickle
from time import time

# %%
def concat_features(pf_paths, contat=False):
    pfs_df = []
    for p in pf_path:
        pf_df = pd.read_csv(p, sep="\s+", index_col=0, engine='python')
    
        special_characters = pf_df.index.str.extractall(r'(?P<square>.*\[.*)')
    
        pf_df.drop(special_characters.square, inplace=True)
    
        pf_df.replace('--undefined--', np.nan, inplace=True)
    
        pf_df = pf_df.astype("float64")
        pfs_df.append(pf_df)
    
    if contat == True:
        p_features = pd.concat(pfs_df)
    else:
        p_features = pfs_df
    return p_features

# %%
pfs_df = []
for p in pf_path:
    pf_df = pd.read_csv(p, sep="\s+", index_col=0, engine='python')
    
    special_characters = pf_df.index.str.extractall(r'(?P<square>.*\[.*)')
    
    pf_df.drop(special_characters.square, inplace=True)
    
    words = [word.strip('\n') for word in pf_df.index]
    
    st = LancasterStemmer()
    words = [st.stem(word) for word in words]
    
    pf_df.index = words
    
    sw = stopwords.words('english')
    stop = [word for word in words if word in sw]
    pf_df.drop(stop, inplace=True)
    
    pf_df.replace('--undefined--', np.nan, inplace=True)
    
    pf_df = pf_df.astype("float64")
    pfs_df.append(pf_df)

# %%
with open('../data/pickles/features_stem_stop.pkl', 'wb') as f:
    pickle.dump(pfs_df, f)

# %%
sw = stopwords.words('english')
print(sw)

# %%
# get doc collections

pf_path = sorted(glob.glob('/Users/the-imitation-gamer/Documents/SLP/Msc_Dissertation/data/pf_means/*/*.means'))
docs = []
for p in pf_path:
    pf_df = pd.read_csv(p, sep="\s+", index_col=0, engine='python')

    special_characters = pf_df.index.str.extractall(r'(?P<square>.*\[.*)')

    pf_df.drop(special_characters.square, inplace=True)
    
    doc = list(pf_df.index)
    doc = [word.strip('\n') for word in doc]
    
    st = LancasterStemmer()
    doc = [st.stem(word) for word in doc]
    
    sw = stopwords.words('english')
    doc = [word for word in doc if word not in sw]
    
#     docs -- list of str
    doc = " ".join(doc)
    docs.append(doc)

# %%
len(docs)
# Out:
# 4874

# %%
with open('./docs_stem_stop.pkl', 'wb') as f:
    pickle.dump(docs, f)

# %%
with open('../data/pickles/docs_stem_stop.pkl', 'rb') as f:
    docs = pickle.load(f)

# %%
with open('../data/pickles/features_stem_stop.pkl', 'rb') as f:
    pfs_df = pickle.load(f)

# %%
tfidf_vectorizer = TfidfVectorizer()

# %%
t0 = time()
tfidf = tfidf_vectorizer.fit_transform(docs)
print("done in %0.3fs." % (time() - t0))
# Out:
# done in 0.996s.

# %%
pf_path = sorted(glob.glob('/Users/the-imitation-gamer/Documents/SLP/Msc_Dissertation/data/pf_means/*/*.means'))
features = concat_features(pf_path)

# %%
term_dict = tfidf_vectorizer.vocabulary_

# %%
t0 = time()

tfidfs = []
words = list(pfs_df[0].index)
# words = [word.strip('\n') for word in words]
for j in range(len(words)):
    if words[j] not in term_dict.keys():
        tfidf_w = 0.01
    else:
        idx_w = term_dict[words[j]]
        tfidf_w = tfidf[0, idx_w]
    print(tfidf_w)
    tfidfs.append(tfidf_w)

print("done in %0.3fs." % (time() - t0))
# Out:
# 0.06413807763716275
# 0.3092295948412856
# 0.15689759407382137
# 0.01
# 0.09647154012976022
# 0.08298109104019702
# 0.32937315788280375
# 0.04675796583362533
# 0.3092295948412856
# 0.10844689601634519
# 0.03623237841207616
# 0.09190876386404949
# 0.10844689601634519
# 0.07595984346576096
# 0.2519114599122689
# 0.01
# 0.28451975220772835
# 0.28451975220772835
# 0.1279699445344229
# 0.1279699445344229
# 0.3092295948412856
# 0.1279699445344229
# 0.09647154012976022
# 0.15679855557811934
# 0.32937315788280375
# 0.04589078619736155
# 0.04675796583362533
# 0.04771235670026707
# 0.28451975220772835
# 0.28451975220772835
# 0.28451975220772835
# 0.28451975220772835
# 0.06449940139485438
# 0.06449940139485438
# 0.07664447718440069
# 0.09579767770495795
# 0.3092295948412856
# 0.06258467720472377
# 0.09647154012976022
# 0.049548290576802156
# 0.05045593191939697
# 0.08644707824403733
# 0.28451975220772835
# 0.028489423351741077
# 0.15689759407382137
# 0.15689759407382137
# 0.046502144692328926
# 0.01
# 0.28451975220772835
# 0.15689759407382137
# 0.040841709462850005
# 0.19400150186808418
# 0.1651681785446426
# 0.19400150186808418
# 0.04589078619736155
# 0.3092295948412856
# 0.11415946766103313
# 0.22490940530018919
# 0.1279699445344229
# 0.0593881360347605
# 0.32937315788280375
# 0.15679855557811934
# 0.3092295948412856
# 0.19400150186808418
# 0.040841709462850005
# 0.11415946766103313
# 0.05350382593509083
# 0.055606680559912365
# 0.32937315788280375
# 0.06143256177772576
# 0.047729921059542636
# 0.08879878247013973
# 0.058420991499219165
# 0.22490940530018919
# 0.055191627627561295
# 0.08565454442885079
# 0.05118057950031735
# 0.048737652257057076
# 0.08644707824403733
# 0.03722640815565952
# 0.09505762942995306
# 0.05920189775580397
# 0.09371637176125047
# 0.08565454442885079
# 0.05118057950031735
# 0.05383257678251375
# 0.06640393871977847
# 0.19400150186808418
# 0.023703032614067025
# 0.05987120723981038
# 0.026889230979180775
# 0.22490940530018919
# 0.05209602284311574
# 0.08565454442885079
# 0.08140839190380494
# 0.08644707824403733
# 0.057513402380009584
# 0.08565454442885079
# 0.06640393871977847
# 0.3092295948412856
# 0.19400150186808418
# 0.046502144692328926
# 0.19400150186808418
# 0.05650353139189681
# 0.08711084412718899
# 0.07730665447308582
# 0.3092295948412856
# 0.19400150186808418
# 0.19400150186808418
# 0.07897978691587403
# 0.3092295948412856
# 0.28451975220772835
# 0.01
# 0.01
# 0.1279699445344229
# 0.07897978691587403
# 0.3092295948412856
# 0.016662808101465313
# 0.06542599226980332
# 0.12138747579921581
# 0.12138747579921581
# 0.3092295948412856
# 0.19400150186808418
# 0.07664447718440069
# 0.05773511584691123
# 0.06143256177772576
# 0.19400150186808418
# 0.2519114599122689
# 0.12018374395441869
# 0.1254813926166932
# 0.09579767770495795
# 0.05609818166292351
# 0.3092295948412856
# 0.01
# 0.01
# 0.10079554385989649
# 0.05045593191939697
# 0.1651681785446426
# 0.3092295948412856
# 0.04958037691744942
# 0.028839276332419776
# 0.07595984346576096
# 0.19400150186808418
# 0.19400150186808418
# 0.07595984346576096
# 0.047729921059542636
# 0.03190669528417692
# 0.08879878247013973
# 0.05541457793722588
# 0.03129011241572155
# 0.12018374395441869
# 0.09437175377764513
# 0.1254813926166932
# 0.09693423730759765
# 0.09653322668601924
# 0.05790361674047449
# 0.06852397186254429
# 0.05957675695756149
# 0.050070244825475965
# 0.07595984346576096
# 0.2519114599122689
# 0.07571118933962125
# 0.28451975220772835
# 0.28451975220772835
# 0.05987120723981038
# 0.05987120723981038
# 0.02154256940763197
# 0.01
# 0.28451975220772835
# 0.01
# 0.10079554385989649
# 0.3092295948412856
# 0.1674090445086867
# 0.1674090445086867
# 0.1279699445344229
# 0.3092295948412856
# 0.05350382593509083
# 0.11121336111982473
# 0.3092295948412856
# 0.22490940530018919
# 0.09647154012976022
# 0.09693423730759765
# 0.1674090445086867
# 0.1674090445086867
# 0.11121336111982473
# 0.2519114599122689
# 0.08059660884492281
# 0.02659578101834588
# 0.28451975220772835
# 0.03504188202622674
# 0.06640393871977847
# 0.01
# 0.048228182821912255
# 0.1651681785446426
# 0.09647154012976022
# 0.3092295948412856
# 0.1651681785446426
# 0.03573642917651102
# 0.05762384235489659
# 0.020744410561370344
# 0.031243734058169385
# 0.07327730835494481
# 0.10330841865161722
# 0.055191627627561295
# 0.05350382593509083
# 0.1651681785446426
# 0.07595984346576096
# 0.06542599226980332
# 0.06281932938918099
# 0.15689759407382137
# 0.15689759407382137
# 0.1674090445086867
# 0.1674090445086867
# 0.030052217103242795
# 0.09579767770495795
# 0.031014005700430072
# 0.09647154012976022
# 0.1674090445086867
# 0.04421940694026585
# 0.1279699445344229
# 0.04421940694026585
# 0.08879878247013973
# 0.22490940530018919
# 0.32937315788280375
# 0.04945244841237751
# 0.05045593191939697
# 0.04022058507300945
# 0.02835938756663348
# 0.06143256177772576
# 0.020568270301101255
# 0.055191627627561295
# 0.28451975220772835
# 0.01
# 0.15689759407382137
# 0.15689759407382137
# 0.01
# 0.28451975220772835
# 0.15689759407382137
# 0.01
# 0.10079554385989649
# 0.3092295948412856
# 0.045362998699503436
# 0.046502144692328926
# 0.01
# 0.15689759407382137
# 0.06143256177772576
# 0.08879878247013973
# 0.023658674046695926
# 0.01
# 0.03504188202622674
# 0.0645788286089836
# 0.08298109104019702
# 0.09579767770495795
# 0.06132122271239397
# 0.039931372137814
# 0.048228182821912255
# 0.03573642917651102
# 0.28451975220772835
# 0.0645788286089836
# 0.08298109104019702
# 0.01
# done in 0.037s.

# %%
t0 = time()

tfidfs = []
nokey = []
for i in range(len(pfs_df)):
    words = list(pfs_df[i].index)
# words = [word.strip('\n') for word in words]
    for j in range(len(words)):
        if words[j] not in term_dict.keys():
            nokey.append(words[j])
            continue
        else:
            idx_w = term_dict[words[j]]
            tfidf_w = tfidf[0, idx_w]
#         print(tfidf_w)
        tfidfs.append(tfidf_w)

print("done in %0.3fs." % (time() - t0))
# Out:
# done in 27.876s.

# %%
len(tfidfs)
# Out:
# 1463657

# %%
nokey
# Out:
# ["i'd",
#  'um-h',
#  "that's",
#  "i'm",
#  "i'm",
#  "that's",
#  "that's",
#  "that's",
#  "that's",
#  'uh-huh',
#  "that's",
#  "that's",
#  "that's",
#  "that's",
#  "that's",
#  'bye-by',
#  "can't",
#  "we'r",
#  "we'r",
#  "junkins'",
#  "ellsworth's",
#  "we'r",
#  "everybody's",
#  'um-h',
#  'um-h',
#  'um-h',
#  "conditioner's",
#  'uh-huh',
#  "there's",
#  "can't",
#  "we'r",
#  "i'm",
#  "i'm",
#  'um-h',
#  "i'm",
#  "there's",
#  "i've",
#  "that's",
#  'good-bye',
#  'um-h',
#  'um-h',
#  "parkinson's",
#  'um-h',
#  'um-h',
#  'i-',
#  'i-',
#  "alzheimer's",
#  "that's",
#  "that's",
#  "they're",
#  "i'm",
#  "i've",
#  "i've",
#  "they've",
#  "what's",
#  'bye-by',
#  "i'd",
#  "there's",
#  'mother-in-law',
#  "there's",
#  "there's",
#  'um-h',
#  'um-h',
#  'um-h',
#  'um-h',
#  'uh-huh',
#  'um-h',
#  "that's",
#  "that's",
#  'um-h',
#  'um-h',
#  'um-h',
#  "that's",
#  "that's",
#  'um-h',
#  'um-h',
#  'um-h',
#  'um-h',
#  'um-h',
#  'um-h',
#  'um-h',
#  'um-h',
#  "that's",
#  'um-h',
#  'um-h',
#  'um-h',
#  "that'd",
#  'um-h',
#  'um-h',
#  'um-h',
#  "that's",
#  'um-h',
#  'um-h',
#  'um-h',
#  'um-h',
#  'um-h',
#  "that's",
#  "they're",
#  "they're",
#  'um-h',
#  'um-h',
#  'um-h',
#  "that's",
#  'bye-by',
#  "i'm",
#  "we'r",
#  "we'r",
#  "i've",
#  "i'm",
#  "there's",
#  'uh-huh',
#  'um-h',
#  'uh-huh',
#  'um-h',
#  'um-h',
#  'um-h',
#  "we'v",
#  "who's",
#  "we'v",
#  "that's",
#  'um-h',
#  'um-h',
#  'um-h',
#  '{alrighty}',
#  'um-h',
#  "we'v",
#  'high-tech',
#  "there's",
#  "they're",
#  '{federaldes}',
#  "guy's",
#  "they're",
#  "i'm",
#  "that's",
#  "can't",
#  "we'r",
#  '{cognizitive}',
#  "i've",
#  "y'all",
#  "y'all",
#  "y'all",
#  "that's",
#  "i've",
#  "i've",
#  'bye-by',
#  "there's",
#  "there's",
#  "they're",
#  "i've",
#  'um-h',
#  'um-h',
#  'um-h',
#  "i'm",
#  "we'r",
#  "can't",
#  "can't",
#  'um-h',
#  'um-h',
#  "that's",
#  'i-',
#  "they're",
#  "that's",
#  "that's",
#  "they're",
#  'um-h',
#  'um-h',
#  'um-h',
#  "that's",
#  "what's",
#  'uh-huh',
#  "that's",
#  "i'm",
#  "there's",
#  'um-h',
#  "that's",
#  "diesel's",
#  'um-h',
#  "i'm",
#  "we'd",
#  "i'm",
#  "they're",
#  "they'll",
#  "i'm",
#  "freon's",
#  "that's",
#  "there's",
#  "that's",
#  "grandfather's",
#  "i'd",
#  "we'r",
#  "i'll",
#  'coca-col',
#  "i've",
#  "i've",
#  "i'm",
#  "i've",
#  "that's",
#  'um-h',
#  'um-h',
#  "here's",
#  'uh-huh',
#  'uh-huh',
#  "they're",
#  "they're",
#  "they're",
#  "i'll",
#  "i've",
#  "that's",
#  "i'm",
#  'part-time',
#  'um-h',
#  "it'll",
#  "that's",
#  'uh-huh',
#  "i'd",
#  'bye-by',
#  "let's",
#  'um-h',
#  'uh-huh',
#  'uh-huh',
#  'uh-huh',
#  "there's",
#  'i-',
#  'uh-huh',
#  'um-h',
#  'um-h',
#  'uh-huh',
#  "they're",
#  "they're",
#  "they're",
#  "i'm",
#  'uh-huh',
#  'uh-hum',
#  'uh-huh',
#  'uh-huh',
#  "i'm",
#  'i-',
#  'uh-huh',
#  'uh-huh',
#  'um-h',
#  "we'r",
#  'um-h',
#  'uh-huh',
#  "we'v",
#  'bye-by',
#  'pop-up',
#  "we'd",
#  'um-h',
#  "i'm",
#  "they're",
#  "that's",
#  "he's",
#  "he's",
#  "we'r",
#  "it'd",
#  'um-h',
#  "i'm",
#  "we'v",
#  "we'v",
#  "we'v",
#  "i've",
#  'pop-up',
#  "they've",
#  "they've",
#  "i've",
#  "that's",
#  "that's",
#  "we'r",
#  "let's",
#  'um-h',
#  "that's",
#  "there's",
#  "i'd",
#  "i'd",
#  "i've",
#  'pop-up',
#  'uh-huh',
#  "that's",
#  'pop-up',
#  "that's",
#  "that's",
#  "that's",
#  "we'v",
#  'bye-by',
#  "i'm",
#  "i've",
#  "that's",
#  "i've",
#  "i'm",
#  'i-',
#  "that's",
#  'i-',
#  'uh-huh',
#  'i-',
#  "there's",
#  "somebody's",
#  "they're",
#  'huh-uh',
#  'uh-huh',
#  'self-satisfaction',
#  "i'd",
#  "i'd",
#  'huh-uh',
#  'i-',
#  'i-',
#  "that's",
#  "i've",
#  "i've",
#  "that's",
#  "he's",
#  "he's",
#  "there's",
#  "they've",
#  "they've",
#  "he's",
#  "he's",
#  "that's",
#  "that's",
#  "we'r",
#  "we'v",
#  'good-bye',
#  "that's",
#  "that's",
#  'uh-huh',
#  "that's",
#  "i'm",
#  "i'm",
#  "people's",
#  "there's",
#  'um-h',
#  'um-h',
#  'um-h',
#  'um-h',
#  'um-h',
#  "there's",
#  "can't",
#  "i'd",
#  "that's",
#  'um-h',
#  'um-h',
#  'um-h',
#  'um-h',
#  'um-h',
#  'um-h',
#  'um-h',
#  'um-h',
#  'um-h',
#  'um-h',
#  'um-h',
#  'um-h',
#  'um-h',
#  "can't",
#  "who's",
#  "can't",
#  "there's",
#  'um-h',
#  "there's",
#  "someone's",
#  "there's",
#  "there's",
#  "there's",
#  "that's",
#  "that's",
#  'um-h',
#  'um-h',
#  "they've",
#  "there's",
#  "i've",
#  "there's",
#  "that's",
#  "jehovah's",
#  "there's",
#  "they're",
#  "that's",
#  "one's",
#  "i'm",
#  "that's",
#  "that's",
#  "that's",
#  "i'm",
#  "i'm",
#  "there's",
#  "there'd",
#  "that's",
#  'um-h',
#  'um-h',
#  "that's",
#  "that'd",
#  'uh-huh',
#  'uh-huh',
#  "that's",
#  'day-to-day',
#  "that's",
#  "i'm",
#  'uh-huh',
#  'um-h',
#  "we'r",
#  "we'r",
#  "that's",
#  "we'v",
#  "that's",
#  "there's",
#  "i'm",
#  "that's",
#  'hum-',
#  "they're",
#  "that's",
#  "that's",
#  "they're",
#  "that's",
#  "they're",
#  'huh-uh',
#  "let's",
#  "i'm",
#  "they've",
#  "that's",
#  "that's",
#  "they've",
#  "they've",
#  "i'm",
#  "i'm",
#  "that's",
#  "everybody's",
#  "i'm",
#  "that's",
#  "that's",
#  "we'r",
#  "that's",
#  "that's",
#  "that's",
#  "we'r",
#  "we'r",
#  "it'll",
#  "that's",
#  "we'll",
#  "where's",
#  "that's",
#  "they're",
#  "that's",
#  "there's",
#  "that's",
#  "i'm",
#  "what'll",
#  "i've",
#  "i'd",
#  "that's",
#  "that's",
#  "we'll",
#  "i'd",
#  "there's",
#  "we'll",
#  "i'm",
#  "we'r",
#  "i'm",
#  "i'm",
#  "where's",
#  "can't",
#  "that's",
#  "we'r",
#  "that's",
#  'hum-',
#  "how's",
#  "that's",
#  "that's",
#  "they're",
#  "they're",
#  "where's",
#  "who's",
#  "i've",
#  "where'd",
#  "that's",
#  'um-h',
#  "there's",
#  "i'm",
#  'i-',
#  'i-',
#  'i-',
#  'i-',
#  "i'm",
#  "let's",
#  'good-bye',
#  'bye-by',
#  "i'd",
#  "i'm",
#  "i'm",
#  "i'm",
#  "that's",
#  'uh-huh',
#  "everybody's",
#  "i'm",
#  "i've",
#  "dad's",
#  "someone's",
#  "i'm",
#  "they're",
#  "they're",
#  "that's",
#  "i've",
#  "they're",
#  "they're",
#  "there'r",
#  "that's",
#  "they're",
#  "that's",
#  "that's",
#  "that's",
#  "they're",
#  "they're",
#  "i'm",
#  "i'm",
#  "they've",
#  "they're",
#  "they'll",
#  "we'v",
#  "they're",
#  "that's",
#  'door-to-do',
#  "would've",
#  "would've",
#  "i'm",
#  "i'll",
#  "i've",
#  "i've",
#  "i've",
#  "there'd",
#  "it'd",
#  "we'v",
#  "i'm",
#  "i've",
#  'uh-huh',
#  'uh-huh',
#  'um-h',
#  "that's",
#  'uh-huh',
#  'uh-huh',
#  'i-',
#  "i've",
#  'uh-huh',
#  'um-h',
#  'um-h',
#  "that's",
#  'um-h',
#  'um-h',
#  'um-h',
#  "that's",
#  "can't",
#  "can't",
#  "i'll",
#  "there's",
#  "they're",
#  "they're",
#  "o'clock",
#  "i've",
#  'um-h',
#  'i-',
#  "that's",
#  'door-to-do',
#  "that's",
#  "that's",
#  "i'm",
#  "that's",
#  "that's",
#  "can't",
#  "we'r",
#  "who've",
#  'uh-huh',
#  'um-h',
#  "i've",
#  'um-h',
#  "that's",
#  'um-h',
#  'um-h',
#  'um-h',
#  "that's",
#  'uh-huh',
#  'um-h',
#  "that's",
#  "that's",
#  "that's",
#  "we'r",
#  "i'm",
#  'um-h',
#  "we'd",
#  'um-h',
#  'um-h',
#  "that's",
#  "that's",
#  "i'm",
#  'um-h',
#  'um-h',
#  "that's",
#  "that's",
#  'bye-by',
#  "i've",
#  "we'r",
#  "we'v",
#  "we'v",
#  '{pricewise}',
#  "there's",
#  "i've",
#  "we'v",
#  "i'm",
#  "we'v",
#  "we'v",
#  "i'm",
#  "i'm",
#  "i'm",
#  "she'll",
#  "i'm",
#  "we'v",
#  'u',
#  'u',
#  'um-h',
#  "i'm",
#  "that's",
#  'um-h',
#  "that's",
#  "that's",
#  "there's",
#  "they're",
#  "can't",
#  'um-h',
#  "can't",
#  "they'll",
#  'um-h',
#  'uh-huh',
#  "that's",
#  "i'm",
#  'um-h',
#  'um-h',
#  'uh-huh',
#  'um-h',
#  "she'll",
#  "i'll",
#  "i'll",
#  "she'll",
#  'um-h',
#  "we'v",
#  "we'r",
#  "we'r",
#  'uh-huh',
#  'um-h',
#  "pta's",
#  'um-h',
#  'um-h',
#  'um-h',
#  'uh-huh',
#  'um-h',
#  "we'v",
#  'um-h',
#  'um-h',
#  'um-h',
#  'bye-by',
#  'um-h',
#  'um-h',
#  "i've",
#  'uh-huh',
#  'um-h',
#  'um-h',
#  "can't",
#  "they're",
#  "they've",
#  'uh-huh',
#  "that'd",
#  'um-h',
#  'um-h',
#  "they've",
#  "what's",
#  "that's",
#  "that's",
#  "that's",
#  'uh-huh',
#  "that's",
#  "that'd",
#  'um-h',
#  "son's",
#  "child's",
#  'um-h',
#  "i've",
#  "doctors'",
#  "dentists'",
#  "that's",
#  "that's",
#  "i've",
#  'uh-huh',
#  "there's",
#  "that's",
#  'bye-by',
#  'uh-huh',
#  '{chowpherd}',
#  '{chowpherd}',
#  "i've",
#  "i'm",
#  "i've",
#  "i'm",
#  'uh-huh',
#  "dog's",
#  "she'd",
#  "that's",
#  "they're",
#  'uh-huh',
#  'uh-huh',
#  'uh-huh',
#  "what's",
#  'uh-huh',
#  'um-h',
#  "we'v",
#  "we'll",
#  "wife's",
#  "i've",
#  "i'd",
#  "that's",
#  "that's",
#  "that's",
#  "that's",
#  'uh-huh',
#  "we'v",
#  "that's",
#  "that's",
#  'um-h',
#  "that's",
#  "that's",
#  "she'll",
#  "what's",
#  "we'v",
#  "that's",
#  "family's",
#  "she'd",
#  "that's",
#  "i've",
#  "that's",
#  'um-h',
#  'um-h',
#  'um-h',
#  'um-h',
#  'uh-huh',
#  'uh-huh',
#  "they're",
#  "that's",
#  "who's",
#  "can't",
#  "i'm",
#  "i'm",
#  "that's",
#  "they're",
#  "can't",
#  'um-h',
#  'um-h',
#  'um-h',
#  'um-h',
#  'um-h',
#  'uh-huh',
#  'uh-huh',
#  'uh-huh',
#  'uh-huh',
#  "we'v",
#  "i've",
#  'i-',
#  "i'm",
#  "there's",
#  "i'm",
#  'i-',
#  "that's",
#  'um-h',
#  'um-h',
#  "may've",
#  "may've",
#  "there'r",
#  "i've",
#  "i'm",
#  "there's",
#  "i've",
#  "they're",
#  "i'm",
#  "i've",
#  "that's",
#  "simon's",
#  "he's",
#  "let's",
#  "let's",
#  "let's",
#  "that's",
#  "they're",
#  "they're",
#  "he's",
#  "he's",
#  "who's",
#  "he's",
#  "i've",
#  "we'v",
#  "i'm",
#  "that's",
#  "y'all",
#  'um-h',
#  'um-h',
#  'um-h',
#  "that's",
#  "we'v",
#  "we'r",
#  "we'v",
#  "we'v",
#  "we'r",
#  "we'll",
#  "that's",
#  "y'all",
#  'uh-huh',
#  "we'r",
#  "we'v",
#  "we'v",
#  "we'r",
#  "we'r",
#  "we'r",
#  'um-h',
#  "we'v",
#  "kid's",
#  'um-h',
#  'um-h',
#  "that's",
#  "we'v",
#  "i'm",
#  "that's",
#  'um-h',
#  "that's",
#  'bye-by',
#  'uh-huh',
#  'uh-huh',
#  'uh-huh',
#  'uh-huh',
#  "we'v",
#  "we'v",
#  "we'v",
#  "we'v",
#  "we'v",
#  'uh-huh',
#  "can't",
#  "can't",
#  "can't",
#  'uh-huh',
#  'uh-huh',
#  'uh-huh',
#  "that's",
#  'uh-huh',
#  "that's",
#  "we'v",
#  "that's",
#  "we'r",
#  'uh-huh',
#  'uh-huh',
#  'uh-huh',
#  'uh-huh',
#  'uh-huh',
#  "we'v",
#  "he's",
#  "that's",
#  'bye-by',
#  "we'v",
#  "husband's",
#  "that's",
#  "that's",
#  "he's",
#  "i've",
#  "that's",
#  "he's",
#  "he's",
#  "how'd",
#  "i'd",
#  "he's",
#  "he's",
#  "he'll",
#  "i'm",
#  "i'm",
#  "he's",
#  "he'll",
#  'wal-mart',
#  'wal-mart',
#  "that's",
#  "let's",
#  'wal-mart',
#  "i'll",
#  "we'd",
#  "i've",
#  "i've",
#  "i'll",
#  "i'm",
#  "i'm",
#  "i've",
#  "i'm",
#  "i'm",
#  '{maxed}',
#  '{maxed}',
#  '{maxed}',
#  "that's",
#  "that's",
#  "that's",
#  "what's",
#  "that's",
#  "i'm",
#  "we'r",
#  "that's",
#  "i'm",
#  "that's",
#  "i'd",
#  "that's",
#  "they've",
#  "they've",
#  "they've",
#  'uh-huh',
#  "that's",
#  "atm's",
#  "they're",
#  "they're",
#  "that's",
#  "there's",
#  "can't",
#  "that's",
#  "there's",
#  "that's",
#  "that's",
#  'uh-huh',
#  "that's",
#  'wal-mart',
#  "we'r",
#  'uh-huh',
#  'um-h',
#  "we'r",
#  "we'r",
#  "i'm",
#  "i'm",
#  "that's",
#  "there's",
#  "we'v",
#  "we'v",
#  "vet's",
#  'huh-uh',
#  "they're",
#  'uh-huh',
#  "can't",
#  'um-h',
#  "let's",
#  "we'v",
#  "i'm",
#  'um-h',
#  'uh-huh',
#  "he's",
#  "we'v",
#  'um-h',
#  'uh-huh',
#  'uh-huh',
#  "that's",
#  'uh-huh',
#  "they're",
#  'i-',
#  "we'v",
#  "i've",
#  'i-',
#  'uh-huh',
#  'uh-huh',
#  "that's",
#  "i'm",
#  "that's",
#  'i-',
#  'self-improvement',
#  'uh-huh',
#  'self-improvement',
#  "i'm",
#  "that's",
#  "that's",
#  "i'm",
#  'good-bye',
#  'good-bye',
#  "i'll",
#  "i'll",
#  'um-h',
#  "that's",
#  'um-h',
#  "that's",
#  'self-improvement',
#  "that's",
#  "that's",
#  "that's",
#  "that's",
#  'self-improvement',
#  "america's",
#  "that's",
#  "i'm",
#  "i'm",
#  'um-h',
#  'um-h',
#  'b',
#  'e',
#  'l',
#  "layman's",
#  'self-improvements',
#  "they're",
#  "they're",
#  "they're",
#  "they're",
#  'um-h',
#  "that's",
#  "we'r",
#  ...]

# %%
nokey_uni = set(nokey)

# %%
len(nokey)
# Out:
# 124779

# %%
print(nokey_uni)
# Out:
# {"gershwin's", 'j', "kid'll", '{bucko}', "barron's", "grade's", "gabriel's", "phone's", "401k's", '{flauge}', '{out-of-towners}', "girls'", "vincent's", "basketball's", 'nitty-gritty', "sportsman's", "bicycling's", "houston's", "somebody'd", "chicago's", 'self-sustaining', "outside's", 'eco-toxicology', "thing's", '{neato}', "country's", 'tune-ups', "controversy's", 'pooh-poohed', "dinner's", "gun's", "backyard's", '{unibody}', '{one-dayer}', 'hang-ups', "quarterback's", "junkins'", 'self-contained', "rangers'", "oregon's", 'avant-garde', "o'brien", '{reaganomics}', '{unsmashed}', 't-ball', "amory's", 'honky-tonk', "he'll", "o'clock", "individual's", "work's", 'upper-class', "kmart's", "penney's", 'un-americ', "rose's", "grandma's", "steve's", "sperry's", '{rechannel}', "hammerstein's", '{closer-knit}', '{stigmatism}', "snow's", "molitor's", "turner's", "brother-in-law's", "rita's", "california's", "arnold's", "leg's", "{dad-in-law's}", '{jordanish}', "granny's", "neighbor's", '{tooken}', "tiffany's", '{himmy}', '{ovolacto}', "town'd", "kennedy's", "movie's", "penny's", "collector's", "jefferson's", 'ex-teacher', "bbc's", "state's", '{babbly}', "smoker's", "physician's", "care's", "states'", "hmo's", "nurse's", "unit's", "station's", "juan's", "denver's", 'g', "poet's", "detector's", 'artsy-craftsy', "valentine'll", "market's", "carradine's", "dan's", 'brother-in-law', "system's", "at&t's", 'rinky-dink', "bombing's", "wednesday's", "amiga's", "children's", "twelve's", "newsprint's", "gentleman's", "pepper's", "chico's", "torito's", 'in-laws', '{unbigoted}', 'f', '{precycling}', "channel's", "nader's", '{bajaing}', 'high-powered', "children'll", "canada's", "burton's", '{anticompetitive}', 'e-systems', "brooks'", 'w-4', 'step-by-step', '{gravityless}', "schwarzenegger's", "usually's", "he'd", '{taxwise}', "garden's", "television's", "coppell's", "victims'", 'half-and-half', 'c-spans', '{misjustice}', "women's", 'old-timey', "toyota's", '{hustly}', "attitude's", "boyfriend's", "industry's", "capone's", 'pre-algebra', "cancer's", "stepdad's", "roma's", "635's", "what'd", "card's", "sierra's", '{antitank}', "imagination's", "energy's", 'door-to-do', "connecticut's", "asimov's", "helman's", '{nonmeal}', "category's", "boys'll", "saab's", "moon's", "louisville's", '{djing}', 'c', "swampers'", "stormin'", 'so-and-so', 'tex-mex', 'pro-life', "general's", "cross-stitching'", "duke's", 'meals-on-wheel', "thousand's", "seven's", 'walkie-talkies', '{sheetrocking}', "we'v", '1', '{depleter}', "teacher's", "flamenco's", 'a&e', "mc's", "tia's", "tracy'd", 'fill-up', 'self-improvement', "hail's", "quarter's", '{stiffy}', 'open-minded', "oggi's", "stepfather's", 'pro-war', 'warm-up', '{antisupporters}', "cheney's", '{anticapitalism}', "austin's", "visa's", "yeltsin's", 'huh-uh', "reynold's", '{incomewise}', "store's", "retirement's", '{antidevelopment}', "that'd", "child's", 'n-th', "temperature's", "brain's", "county's", "crowd's", "community's", "cats'", "germany's", 'up-to-date', "stephen's", "floor's", "everybody's", "garcia's", '{taxachusetts}', 'v-6', 'wal-mart', "neal's", "texan's", "lawrey's", '{techy}', '{sportswise}', 'short-term', "razor's", "apple's", "adult's", 'half-life', 'shut-ins', "cpa's", "pizza's", "hitchhiker's", "bogart's", 'c-span', "russia's", "rugby's", "half's", "tree's", 'one-on-on', "shopper's", "carpet's", "minneapolis'", '{schmeal}', "topic's", "egypt's", "amrein's", "anthony's", 'cross-stitching', '{administaff}', 'non-hunting', 'great-aunt', '{disclaimerage}', "bank's", '{himmys}', "clock's", "alley's", "blow's", "tonight's", "b's", "job's", "politician's", "supervisor's", "chicken's", "karate's", 'full-scale', "ham's", "snail's", "wife's", "nfl's", "there'r", 'well-known', "exercising's", "graveyard's", "nra's", '{wolmanized}', "golfer's", "something's", 'rip-off', 'right-hander', "checkbook's", 'fill-ins', "magazine's", "brothers'", "what's", "doc's", 'high-tech', "guys'll", 'carry-on', "allen's", "shoney's",  ...

# %%
len(nokey_uni)
# Out:
# 1950

# %%
with open('../data/pickles/tfidfs.pkl', 'wb') as f:
    pickle.dump(tfidfs, f)

# %%
len(tfidfs)
# Out:
# 1588436

# %%
p_features = pd.concat(pfs_df)

# %%
p_features.drop(nokey_uni, inplace=True)

# %%
len(p_features)
# Out:
# 1463657

# %%
def correlation(features, values, absolute=False): # features--pd.df, values -- list/array
    corrs = []
    pvalues = []
    for feature in features.columns[0:11]:
        print('\n' + feature)
        feature_np = features[feature].to_numpy()
        
        if absolute == True:
            feature_np = np.absolute(feature_np)
            
        values = np.array(values)
#         values[np.isnan(values)] = 0.00001
        feature_np[np.isnan(feature_np)] = 0.00001
        corr = spearmanr(feature_np, values)
        
        corrs.append(corr[0])
        print('spearman: ', corr)
        pvalues.append(corr[1])
        
    index = ['Spearman', 'p-value']
    columns = list(features.columns)
    result = pd.DataFrame(np.array([corrs, pvalues]), index=index, columns=columns).round(2)
        
    return result

# %%
result = correlation(p_features, tfidfs, absolute=True)
# Out:
# maxf0
# spearman:  SpearmanrResult(correlation=-0.042748294636169734, pvalue=0.0)
#
# minf0
# spearman:  SpearmanrResult(correlation=0.021067291760196734, pvalue=2.5205599603507072e-143)
#
# excursion_size
# spearman:  SpearmanrResult(correlation=-0.12848527427764128, pvalue=0.0)
#
# meanf0
# spearman:  SpearmanrResult(correlation=-0.05627645461033071, pvalue=0.0)
#
# finalf0
# spearman:  SpearmanrResult(correlation=-0.001313733410683094, pvalue=0.1119754737393214)
#
# mean_intensity
# spearman:  SpearmanrResult(correlation=-0.02152251948677203, pvalue=1.687962157500482e-149)
#
# duration
# spearman:  SpearmanrResult(correlation=-0.2394975119703252, pvalue=0.0)
#
# max_velocity
# spearman:  SpearmanrResult(correlation=-0.08394545368524234, pvalue=0.0)
#
# final_velocity
# spearman:  SpearmanrResult(correlation=-0.027370450514932226, pvalue=1.561949895102288e-240)
#
# maxf0_loc_ms
# spearman:  SpearmanrResult(correlation=-0.16604191742696175, pvalue=0.0)
#
# maxf0_loc_ratio
# spearman:  SpearmanrResult(correlation=-0.05790662539077734, pvalue=0.0)

# %%
result.to_csv('../result/all_data_tfidf_abs.csv')
